# %%
from collections import namedtuple
import inference_gym.using_jax as gym
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import os
print(os.listdir())
import sys
# sys.path.append('..')
sys.path.append('../../../sampler-comparison')
# sys.path.append('../../')
from sampler_comparison.samplers import samplers
# import seaborn as sns

from sampler_evaluation.models import models
from sampler_evaluation.models.standardgaussian import Gaussian


import pymc as pm
import numpy as np

import pymc
from pymc.sampling.jax import get_jaxified_logp

# import numpyro
# import numpyro.distributions as dist
# from numpyro.infer.reparam import TransformReparam
# Out:
# 2025-02-18 14:20:49.164971: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739917249.181184 1551583 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739917249.186192 1551583 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-18 14:20:49.205395: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ['debug.ipynb', 'other_ppls.ipynb', 'debug.py', 'demo.ipynb', 'other_ppls_2.ipynb']
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# ['debug.ipynb', 'other_ppls.ipynb', 'debug.py', 'demo.ipynb', 'other_ppls_2.ipynb']
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)
# /global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:68: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return lax_numpy.astype(arr, dtype, copy=copy, device=device)

# %%
# True parameter values
alpha, sigma = 1, 1
beta = [1, 2.5]

# Size of dataset
size = 100

# Predictor variable
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.2

RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)

# Simulate outcome variable
Y = alpha + beta[0] * X1 + beta[1] * X2 + rng.normal(size=size) * sigma



basic_model = pm.Model()

with basic_model as model:
    # Priors for unknown model parameters
    alpha = pm.Normal("alpha", mu=0, sigma=10)
    beta = pm.Normal("beta", mu=0, sigma=10, shape=2)
    sigma = pm.HalfNormal("sigma", sigma=1)


    # Expected value of outcome
    mu = alpha + beta[0] * X1 + beta[1] * X2

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=Y)


# J = 8
# y = np.array([28.0, 8.0, -3.0, 7.0, -1.0, 1.0, 18.0, 12.0])
# sigma = np.array([15.0, 10.0, 16.0, 11.0, 9.0, 11.0, 10.0, 18.0])


# with pm.Model() as model:

#     mu = pm.Normal("mu", mu=0.0, sigma=10.0)
#     tau = pm.HalfCauchy("tau", 5.0)

#     theta = pm.Normal("theta", mu=0, sigma=1, shape=J)
#     theta_1 = mu + tau * theta
#     obs = pm.Normal("obs", mu=theta_1, sigma=sigma, shape=J, observed=y)



# def eight_schools_noncentered(J, sigma, y=None):
#     mu = numpyro.sample("mu", dist.Normal(0, 5))
#     tau = numpyro.sample("tau", dist.HalfCauchy(5))
#     with numpyro.plate("J", J):
#         with numpyro.handlers.reparam(config={"theta": TransformReparam()}):
#             theta = numpyro.sample(
#                 "theta",
#                 dist.TransformedDistribution(
#                     dist.Normal(0.0, 1.0), dist.transforms.AffineTransform(mu, tau)
#                 ),
#             )
#         numpyro.sample("obs", dist.Normal(theta, sigma), obs=y)

get_jaxified_logp(model)
# from numpyro.infer.util import initialize_model
# Out:
# WARNING (pytensor.link.c.cmodule): Deleting (Broken cache directory [EOF]): /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpgt0zm0z8
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(10)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpnlcw58ld/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpnlcw58ld/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_i26tpqgg
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpc1io_gyv/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpc1io_gyv/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_pr6r4sx6
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(10)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpbl5pr089/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpbl5pr089/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_h_jda_kp
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmp_p1kydn_/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmp_p1kydn_/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_56h211eu
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(10)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpflxsrosg/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpflxsrosg/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_zgp1xhwz
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpa7zli79k/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpa7zli79k/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_fu8h4987
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(2)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpn3ikx1gv/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpn3ikx1gv/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_6cweys1c
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(10)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmp9yu6ra4z/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmp9yu6ra4z/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_hi3_3cgu
# ...
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpfwd0e4wj/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpfwd0e4wj/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_vweve3g6
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(2)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmp5q1sklok/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmp5q1sklok/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_qjcd528b
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(10)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /global/homes/r/reubenh/.conda/envs/jax2024/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=znver3 -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -msse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mvpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mclwb -mclzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mno-hle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mmwaitx -mno-pconfig -mpku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mrdpid -mrdrnd -mrdseed -mno-rtm -mno-serialize -mno-sgx -msha -mshstk -mno-tbm -mno-tsxldtrk -mvaes -mno-waitpkg -mwbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=znver3 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/numpy/core/include -I/global/homes/r/reubenh/.conda/envs/jax2024/include/python3.11 -I/global/homes/r/reubenh/.conda/envs/jax2024/lib/python3.11/site-packages/pytensor/link/c/c_code -L/global/homes/r/reubenh/.conda/envs/jax2024/lib -fvisibility=hidden -o /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpf51_e_up/m28288347be280590711df7f10b238d4d5253fc39b446812334918942c17f17af.so /global/u1/r/reubenh/.pytensor/compiledir_Linux-5.14-111_12.0.91-cray_shasta_c-x86_64-with-glibc2.31-x86_64-3.11.9-64/tmpf51_e_up/mod.cpp -lpython3.11
# /global/u1/r/reubenh/.conda/envs/jax2024/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: final link failed: Disk quota exceeded
# collect2: error: ld returned 1 exit status
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_je66ti1l
# library inux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: is not found.
# <function pymc.sampling.jax.get_jaxified_logp.<locals>.logp_fn_wrap(x: Union[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]], numpy._typing._nested_sequence._NestedSequence[numpy._typing._array_like._SupportsArray[numpy.dtype[Any]]], bool, int, float, complex, str, bytes, numpy._typing._nested_sequence._NestedSequence[Union[bool, int, float, complex, str, bytes]]]) -> jax.Array>
